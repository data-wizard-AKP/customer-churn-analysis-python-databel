# %%
# %pip install numpy
# %pip install pandas
# %pip install scikit-learn
# %pip install matplotlib
# %pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')

# %%
# Loading Data
df = pd.read_csv("Databel - Data.csv")
df.head(3)
# Out:
#   Customer ID Churn Label  Account Length (in months)  Local Calls  \
# 0   4444-BZPU          No                           1            3
# 1   5676-PTZX          No                          33          179
# 2   8532-ZEKQ          No                          44           82
#
#    Local Mins  Intl Calls  Intl Mins Intl Active Intl Plan  \
# 0         8.0         0.0        0.0          No        no
# 1       431.3         0.0        0.0          No        no
# 2       217.6         0.0        0.0          No       yes
#
#    Extra International Charges  ...  Senior  Group  \
# 0                          0.0  ...      No     No
# 1                          0.0  ...      No     No
# 2                          0.0  ...      No     No
#
#   Number of Customers in Group  Device Protection & Online Backup  \
# 0                            0                                 No
# 1                            0                                Yes
# 2                            0                                Yes
#
#     Contract Type Payment Method Monthly Charge  Total Charges Churn Category  \
# 0  Month-to-Month   Direct Debit             10             10            NaN
# 1        One Year    Paper Check             21            703            NaN
# 2        One Year   Direct Debit             23           1014            NaN
#
#   Churn Reason
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 29 columns]

# %% [markdown]
# # **Data Check**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6687 entries, 0 to 6686
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        6687 non-null   object
#  1   Churn Label                        6687 non-null   object
#  2   Account Length (in months)         6687 non-null   int64
#  3   Local Calls                        6687 non-null   int64
#  4   Local Mins                         6687 non-null   float64
#  5   Intl Calls                         6687 non-null   float64
#  6   Intl Mins                          6687 non-null   float64
#  7   Intl Active                        6687 non-null   object
#  8   Intl Plan                          6687 non-null   object
#  9   Extra International Charges        6687 non-null   float64
#  10  Customer Service Calls             6687 non-null   int64
#  11  Avg Monthly GB Download            6687 non-null   int64
#  12  Unlimited Data Plan                6687 non-null   object
#  13  Extra Data Charges                 6687 non-null   int64
#  14  State                              6687 non-null   object
#  15  Phone Number                       6687 non-null   object
#  16  Gender                             6687 non-null   object
#  17  Age                                6687 non-null   int64
#  18  Under 30                           6687 non-null   object
#  19  Senior                             6687 non-null   object
#  20  Group                              6687 non-null   object
#  21  Number of Customers in Group       6687 non-null   int64
#  22  Device Protection & Online Backup  6687 non-null   object
#  23  Contract Type                      6687 non-null   object
#  24  Payment Method                     6687 non-null   object
#  25  Monthly Charge                     6687 non-null   int64
#  26  Total Charges                      6687 non-null   int64
#  27  Churn Category                     1769 non-null   object
#  28  Churn Reason                       1769 non-null   object
# dtypes: float64(4), int64(9), object(16)
# memory usage: 1.5+ MB

# %%
# Heatmap for check Null Values
sns.heatmap(df.isnull())
print("No Null Values in DataSet")
# Out:
# No Null Values in DataSet

# %% [markdown]
# > *There is only null values in Churn Reason*

# %%
import warnings
warnings.filterwarnings('ignore')
print(f"Columns : {df.shape[0]} \nRows : {df.shape[1]}")
# Out:
# Columns : 6687
# Rows : 29

# %%
df.describe()
# Out:
#        Account Length (in months)  Local Calls   Local Mins   Intl Calls  \
# count                 6687.000000  6687.000000  6687.000000  6687.000000
# mean                    32.337820   130.974129   322.752864    51.097524
# std                     24.595689   121.893966   288.619931   103.592369
# min                      1.000000     1.000000     4.000000     0.000000
# 25%                      9.000000    31.000000    76.900000     0.000000
# 50%                     29.000000    98.000000   250.500000     0.000000
# 75%                     55.000000   199.000000   498.050000    52.000000
# max                     77.000000   918.000000  1234.200000  1120.000000
#
#          Intl Mins  Extra International Charges  Customer Service Calls  \
# count  6687.000000                  6687.000000             6687.000000
# mean    130.070624                    33.641783                0.915657
# std     243.527828                    76.346828                1.411484
# min       0.000000                     0.000000                0.000000
# 25%       0.000000                     0.000000                0.000000
# 50%       0.000000                     0.000000                0.000000
# 75%     140.400000                    16.400000                2.000000
# max    1372.500000                   585.800000                5.000000
#
#        Avg Monthly GB Download  Extra Data Charges          Age  \
# count              6687.000000         6687.000000  6687.000000
# mean                  6.696276            3.374458    47.448632
# std                   7.454339           12.565309    16.969893
# min                   0.000000            0.000000    19.000000
# 25%                   1.000000            0.000000    33.000000
# 50%                   5.000000            0.000000    47.000000
# 75%                   9.000000            0.000000    60.000000
# max                  43.000000           99.000000    85.000000
#
#        Number of Customers in Group  Monthly Charge  Total Charges
# count                   6687.000000     6687.000000    6687.000000
# mean                       0.837894       31.030357    1083.755645
# std                        1.700780       16.288147    1127.074863
# min                        0.000000        5.000000       6.000000
# 25%                        0.000000       16.000000     181.000000
# 50%                        0.000000       31.000000     647.000000
# 75%                        0.000000       43.000000    1732.500000
# max                        6.000000       78.000000    5574.000000

# %%
df.describe(include="object").transpose()
# Out:
#                                   count unique                           top  \
# Customer ID                        6687   6687                     4444-BZPU
# Churn Label                        6687      2                            No
# Intl Active                        6687      2                            No
# Intl Plan                          6687      2                            no
# Unlimited Data Plan                6687      2                           Yes
# State                              6687     51                            WV
# Phone Number                       6687   6677                      359-9794
# Gender                             6687      3                          Male
# Under 30                           6687      2                            No
# Senior                             6687      2                            No
# Group                              6687      2                            No
# Device Protection & Online Backup  6687      2                            No
# Contract Type                      6687      3                Month-to-Month
# Payment Method                     6687      3                  Direct Debit
# Churn Category                     1769      5                    Competitor
# Churn Reason                       1769     20  Competitor made better offer
#
#                                    freq
# Customer ID                           1
# Churn Label                        4891
# Intl Active                        4116
# Intl Plan                          6036
# Unlimited Data Plan                4494
# State                               213
# Phone Number                          2
# Gender                             3379
# Under 30                           5400
# Senior                             5460
# Group                              5166
# Device Protection & Online Backup  4393
# Contract Type                      3411
# Payment Method                     3702
# Churn Category                      805
# Churn Reason                        303

# %%
df.head(3)
# Out:
#   Customer ID Churn Label  Account Length (in months)  Local Calls  \
# 0   4444-BZPU          No                           1            3
# 1   5676-PTZX          No                          33          179
# 2   8532-ZEKQ          No                          44           82
#
#    Local Mins  Intl Calls  Intl Mins Intl Active Intl Plan  \
# 0         8.0         0.0        0.0          No        no
# 1       431.3         0.0        0.0          No        no
# 2       217.6         0.0        0.0          No       yes
#
#    Extra International Charges  ...  Senior  Group  \
# 0                          0.0  ...      No     No
# 1                          0.0  ...      No     No
# 2                          0.0  ...      No     No
#
#   Number of Customers in Group  Device Protection & Online Backup  \
# 0                            0                                 No
# 1                            0                                Yes
# 2                            0                                Yes
#
#     Contract Type Payment Method Monthly Charge  Total Charges Churn Category  \
# 0  Month-to-Month   Direct Debit             10             10            NaN
# 1        One Year    Paper Check             21            703            NaN
# 2        One Year   Direct Debit             23           1014            NaN
#
#   Churn Reason
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 29 columns]

# %% [markdown]
# # EDA

# %%
print(f"Total Number of Customers: {df['Customer ID'].nunique()}")
print(f"Total NUmber of Churned Customers: {df['Churn Label'].value_counts()[1]}")
print(f"Rate of Churned Customers : {(df['Churn Label'].value_counts()[1]/df['Customer ID'].nunique()*100).round(2)} %")
# Out:
# Total Number of Customers: 6687
# Total NUmber of Churned Customers: 1796
# Rate of Churned Customers : 26.86 %

# %%
reason=df[df['Churn Label'] == 'Yes'][['Churn Label','Churn Reason','Churn Category']]

# %%
#Find Churn Reason
churn_reason=reason['Churn Reason'].value_counts().reset_index()
churn_reason.head(3)
# Out:
#                     Churn Reason  count
# 0   Competitor made better offer    303
# 1  Competitor had better devices    297
# 2     Attitude of support person    203

# %%
## Create a barplot which Will Show the Churn Reason
sns.barplot(x='count',y='Churn Reason',data=churn_reason,palette='Blues_r')
plt.title('Count of Churn Reason',fontweight='bold',fontsize=15)
plt.ylabel('Churn Reason',fontweight='bold',fontsize=15)
plt.xlabel('Count',fontweight='bold',fontsize=15)
plt.show()

# %%
churned=df[df['Churn Label'] == 'Yes'].groupby('Account Length (in months)')['Churn Label'].count().reset_index(name='Churned')
retained=df[df['Churn Label'] == 'No'].groupby('Account Length (in months)')['Churn Label'].count().reset_index(name='Not Churned')
merged_df = pd.merge(churned, retained, on='Account Length (in months)', how='inner')
merged_df.head()
# Out:
#    Account Length (in months)  Churned  Not Churned
# 0                           1      367          224
# 1                           2      117          108
# 2                           3       82          106
# 3                           4       80           81
# 4                           5       60           78

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='Account Length (in months)',y='Not Churned',data=merged_df,label='Not Churned',linewidth=2,color='blue')
sns.lineplot(x='Account Length (in months)',y='Churned',data=merged_df,label='Churned',linestyle='--',linewidth=2,color='red')
plt.ylabel('Churned',fontweight='bold',fontsize=15)
plt.xlabel('Account Length (in months)',fontweight='bold',fontsize=15)
plt.legend(fontsize='large')
plt.show()

# %%
reason['Churn Category'].value_counts()
labels=reason['Churn Category'].value_counts().index

# %%
import matplotlib.pyplot as plt

# Example data
exp = [0.05, 0, 0, 0, 0]
col = ['#FF9999','#66B3FF','#99FF99','#FFCC99','#FFD700']


# Prepare data for Values and label
values = reason['Churn Category'].value_counts()
labels = values.index
exp = [0.05] + [0] * (len(values) - 1)  # explode only the first slice

# Generate professional blue palette
col = sns.color_palette("Blues_r", len(values))

# Plot pie chart
plt.figure(figsize=(7, 7))
plt.pie(x=values.values,
        explode=exp,
        autopct="%1.1f%%",
        shadow=True,
        radius=1,
        colors=col,
        textprops={"fontsize": 10, "fontweight": 'bold'},
        wedgeprops={"linewidth": 1, "edgecolor": 'black'},
        rotatelabels=False,
        startangle=50)

plt.legend(labels, bbox_to_anchor=(1, 1))
plt.title("Churn Categories", fontsize=15, fontweight='bold')
plt.show()

# %%
# Set a dark professional palette
with sns.color_palette("dark"):
    # Create a 3x2 grid of subplots
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 20))

    # Plot 6 categorical features against Churn Label
    sns.countplot(x="Contract Type", data=df, hue="Churn Label", ax=axes[0, 0])
    sns.countplot(x="Payment Method", data=df, hue="Churn Label", ax=axes[0, 1])
    sns.countplot(x="Gender", data=df, hue="Churn Label", ax=axes[1, 0])
    sns.countplot(x="Intl Plan", data=df, hue="Churn Label", ax=axes[1, 1])
    sns.countplot(x="Unlimited Data Plan", data=df, hue="Churn Label", ax=axes[2, 0])
    sns.countplot(x="Under 30", data=df, hue="Churn Label", ax=axes[2, 1])

    # Set overall spacing
    plt.tight_layout()
    plt.show()

# %%
cor=df[['Account Length (in months)','Local Calls', 'Local Mins', 'Intl Calls', 'Intl Mins','Extra International Charges', 
    'Customer Service Calls','Avg Monthly GB Download', 'Extra Data Charges', 'Age',
    'Number of Customers in Group', 'Monthly Charge', 'Total Charges']].corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(cor,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
values=[df['Customer ID'].nunique(),df['Churn Label'].value_counts()[1],(df['Churn Label'].value_counts()[1]/df['Customer ID'].nunique()*100).round(2)]

# %%
metric=["Total Number of Customers","Total NUmber of Churned Customers","Rate of Churned Customers"]

# %%
summary=pd.DataFrame({'metric':metric,'Values':values},index=range(1,4))
summary
# Out:
#                               metric   Values
# 1          Total Number of Customers  6687.00
# 2  Total NUmber of Churned Customers  1796.00
# 3          Rate of Churned Customers    26.86

# %%
df.groupby('Contract Type')['Avg Monthly GB Download'].mean().reset_index(name='Avg Monthly GB Download')
# Out:
#     Contract Type  Avg Monthly GB Download
# 0  Month-to-Month                 7.154500
# 1        One Year                 6.934415
# 2        Two Year                 5.630495

# %%
with sns.color_palette("dark"):
    plt.figure(figsize=(11,7))
    sns.lmplot(y='Total Charges',x='Account Length (in months)',data=df,hue='Churn Label',
           col='Contract Type')

# %%
print("Majorit of Our Customers")
df['State'].value_counts().head().reset_index(name='No. of Customers')
# Out:
# Majorit of Our Customers
#   State  No. of Customers
# 0    WV               213
# 1    MN               168
# 2    NY               167
# 3    AL               161
# 4    OH               158

# %%
df[df['Churn Label']=='Yes']['State'].value_counts().reset_index(name='Customer Churned').head(5)
# Out:
#   State  Customer Churned
# 0    WV                57
# 1    OH                55
# 2    OR                48
# 3    MD                46
# 4    AL                46

# %% [markdown]
# * *Majority of our customers from West Virginia US state(WV)*
# * *Most of the customers is also churned from WV*

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
column_selection=df[['Churn Label', 'Account Length (in months)',
       'Local Calls', 'Local Mins', 'Intl Calls', 'Intl Mins', 'Intl Active',
       'Intl Plan', 'Extra International Charges', 'Customer Service Calls',
       'Avg Monthly GB Download', 'Unlimited Data Plan', 'Extra Data Charges',
        'Gender', 'Age', 'Under 30', 'Senior', 'Group',
       'Number of Customers in Group', 'Device Protection & Online Backup',
       'Contract Type', 'Payment Method', 'Monthly Charge', 'Total Charges',
       'Churn Category','Churn Reason']]
column_selection.head(3)
# Out:
#   Churn Label  Account Length (in months)  Local Calls  Local Mins  \
# 0          No                           1            3         8.0
# 1          No                          33          179       431.3
# 2          No                          44           82       217.6
#
#    Intl Calls  Intl Mins Intl Active Intl Plan  Extra International Charges  \
# 0         0.0        0.0          No        no                          0.0
# 1         0.0        0.0          No        no                          0.0
# 2         0.0        0.0          No       yes                          0.0
#
#    Customer Service Calls  ...  Senior Group  Number of Customers in Group  \
# 0                       0  ...      No    No                             0
# 1                       0  ...      No    No                             0
# 2                       0  ...      No    No                             0
#
#   Device Protection & Online Backup   Contract Type Payment Method  \
# 0                                No  Month-to-Month   Direct Debit
# 1                               Yes        One Year    Paper Check
# 2                               Yes        One Year   Direct Debit
#
#   Monthly Charge Total Charges  Churn Category Churn Reason
# 0             10            10             NaN          NaN
# 1             21           703             NaN          NaN
# 2             23          1014             NaN          NaN
#
# [3 rows x 26 columns]

# %%
features=column_selection.drop('Churn Label',axis=1)
X=pd.get_dummies(features,drop_first=True)
y=df['Churn Label']

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.5, random_state=42)

# %%
logmodel=linear_model.LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions=logmodel.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.89      0.93      0.91      2447
#          Yes       0.79      0.68      0.73       897
#
#     accuracy                           0.87      3344
#    macro avg       0.84      0.81      0.82      3344
# weighted avg       0.86      0.87      0.86      3344

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[2282  165]
#  [ 283  614]]

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.8660287081339713

# %% [markdown]
# # **ACCURACY 86.60 %**
